# %%
import cryptocompare
#from datetime import datetime
import datetime

import csv
import time
import numpy as np
#Para la función crear_dir
import os
import errno

import threading
threads=10

# %%
def main():
    #Una lista de todas todas las monedas
    coins=cryptocompare.get_coin_list(format=True)
    coins=['ETH']

    #Definimos una fecha inicial y calculamos la distancia de días con la actual
    print("Definiendo la fecha inicial:")
    from datetime import date
    date0 = date(2021, 1, 1)
    today = date.today()
    delta = today - date0
    print(delta.days)
    print (date0)

    #date0 = datetime(2021, 1, 1)

    #Obtenemos el historico de precios, uno por día
    for i in coins:
        #Creamos los directrios para cada moneda y los ficheros respectivos
        crear_dir(i)#Creamos un directorio con el nombre de la moneda

        file = open(str(i)+"/"+"outFile.csv", "a")
        csvWriter = csv.writer( file )

        header = ['Nombre', 'Fecha', 'Precio']
        csvWriter.writerow( header )

        fecha=date0
        j=1
        print("Antes de while")
        while j < int(delta.days):
                print("Dentro del while con valor de delta.days: ",delta.days)
                for k in range(threads):
                    if(j<=int(delta.days)):
                        print("Hilo nº ",k)
                        t=threading.Thread(target=func_hilo(fecha, i, csvWriter))
                        t.start()
                        fecha += datetime.timedelta(days=1)
                        j=j+1
                        print("EL VALOR DE J: ", j)
                    else:
                        pass

# %%
def crear_dir(nombre_dir):
    print("Creando el directorio ", nombre_dir)
    try:
        os.mkdir(nombre_dir)
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise

# %%
def func_hilo(fecha, i, csvWriter):
    print("Precios para la fecha: ", str(fecha))
    precio=cryptocompare.get_historical_price(i, 'USD', fecha)
    data=[i, fecha, precio]
    csvWriter.writerow( data)

    print("Antes de sumarle un dia a la fecha")
    print(type(fecha))

# %%
main()
# Out:
# Definiendo la fecha inicial:
# 34
# 2021-01-01
# Creando el directorio  ETH
# Antes de while
# Dentro del while con valor de delta.days:  34
# Hilo nº  0
# Precios para la fecha:  2021-01-01
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  2
# Hilo nº  1
# Precios para la fecha:  2021-01-02
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  3
# Hilo nº  2
# Precios para la fecha:  2021-01-03
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  4
# Hilo nº  3
# Precios para la fecha:  2021-01-04
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  5
# Hilo nº  4
# Precios para la fecha:  2021-01-05
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  6
# Hilo nº  5
# Precios para la fecha:  2021-01-06
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  7
# Hilo nº  6
# Precios para la fecha:  2021-01-07
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  8
# Hilo nº  7
# Precios para la fecha:  2021-01-08
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  9
# Hilo nº  8
# Precios para la fecha:  2021-01-09
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  10
# Hilo nº  9
# Precios para la fecha:  2021-01-10
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  11
# Dentro del while con valor de delta.days:  34
# Hilo nº  0
# Precios para la fecha:  2021-01-11
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  12
# Hilo nº  1
# Precios para la fecha:  2021-01-12
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  13
# Hilo nº  2
# Precios para la fecha:  2021-01-13
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  14
# Hilo nº  3
# Precios para la fecha:  2021-01-14
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  15
# Hilo nº  4
# Precios para la fecha:  2021-01-15
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  16
# Hilo nº  5
# Precios para la fecha:  2021-01-16
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  17
# Hilo nº  6
# Precios para la fecha:  2021-01-17
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  18
# Hilo nº  7
# Precios para la fecha:  2021-01-18
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  19
# Hilo nº  8
# Precios para la fecha:  2021-01-19
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  20
# Hilo nº  9
# Precios para la fecha:  2021-01-20
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  21
# Dentro del while con valor de delta.days:  34
# Hilo nº  0
# Precios para la fecha:  2021-01-21
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  22
# Hilo nº  1
# Precios para la fecha:  2021-01-22
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  23
# Hilo nº  2
# Precios para la fecha:  2021-01-23
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  24
# Hilo nº  3
# Precios para la fecha:  2021-01-24
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  25
# Hilo nº  4
# Precios para la fecha:  2021-01-25
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  26
# Hilo nº  5
# Precios para la fecha:  2021-01-26
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  27
# Hilo nº  6
# Precios para la fecha:  2021-01-27
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  28
# Hilo nº  7
# Precios para la fecha:  2021-01-28
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  29
# Hilo nº  8
# Precios para la fecha:  2021-01-29
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  30
# Hilo nº  9
# Precios para la fecha:  2021-01-30
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  31
# Dentro del while con valor de delta.days:  34
# Hilo nº  0
# Precios para la fecha:  2021-01-31
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  32
# Hilo nº  1
# Precios para la fecha:  2021-02-01
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  33
# Hilo nº  2
# Precios para la fecha:  2021-02-02
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  34
# Hilo nº  3
# Precios para la fecha:  2021-02-03
# Antes de sumarle un dia a la fecha
# <class 'datetime.date'>
# EL VALOR DE J:  35
